# %% [markdown]
# # Instructions
# On this first assignment, applying the basic functions of the Igraph package is required. The following datasets are going to be used:
#
# * Actors dataset - undirected graph - : For the 2005 Graph Drawing conference a data set was provided of the IMDB movie database. We will use a reduced version of this dataset, which derived all actor-actor collaboration edges where the actors co-starred in at least 2 movies together between 1995 and 2004.
#
#
# You have to complete the code chunks in this document but also analyze the results, extract insights and answer the short questions. Fill the CSV attached with your answers, sometimes just the number is enough, some others just a small sentence or paragraph. Remember to change the header with your email.
#
# In your submission please upload both this document in HTML and the CSV with the solutions.
#
#
# # Loading data
#
# In this section, the goal is loading the datasets given, building the graph and analyzing basics metrics. Include the edge or node attributes you consider.
#
# Describe the values provided by summary function on the graph object.

# %%
from igraph import *
import cairo
import pandas as pd
import plotly.express as px

actorsdf = pd.read_csv('/Users/francoandresbenvenuto/Downloads/imdb_actors_key.tsv', sep='\t',encoding= 'unicode_escape')

actorsdf.head(10)
# Out:
#       id                 name  movies_95_04 main_genre  \
# 0  15629  Rudder, Michael (I)            12   Thriller
# 1   5026        Morgan, Debbi            16      Drama
# 2  11252         Bellows, Gil            33      Drama
# 3   5150         Dray, Albert            20     Comedy
# 4   4057      Daly, Shane (I)            18      Drama
# 5  12373     Macfadyen, Angus            24      Drama
# 6   3453         Djola, Badja            11      Drama
# 7   9878               Twiggy            12      Music
# 8   4988       Winfrey, Oprah            21      Music
# 9  13032       Champagne (II)            11      Adult
#
#                                               genres
# 0  Action:1,Comedy:1,Drama:1,Fantasy:1,Horror:1,N...
# 1  Comedy:2,Documentary:1,Drama:6,Horror:2,NULL:3...
# 2  Comedy:6,Documentary:1,Drama:7,Family:1,Fantas...
# 3  Comedy:6,Crime:1,Documentary:1,Drama:4,NULL:5,...
# 4  Comedy:2,Crime:1,Drama:7,Horror:1,Music:1,Musi...
# 5  Action:1,Adventure:1,Documentary:1,Drama:7,Fam...
# 6                         Adult:1,Drama:7,Thriller:3
# 7            Documentary:5,Drama:1,Music:4,Romance:2
# 8  Comedy:1,Documentary:8,Drama:1,Family:1,Music:...
# 9                                     Adult:8,NULL:3

# %%
edges_actorsdf = pd.read_csv('/Users/francoandresbenvenuto/Downloads/imdb_actor_edges.tsv', sep='\t',encoding= 'unicode_escape')

edges_actorsdf.head(10)
# Out:
#     from     to  weight
# 0  17776  17778       6
# 1   5578   9770       3
# 2   5578    929       2
# 3   5578   9982       2
# 4   1835   6278       2
# 5   1835   1664       7
# 6   1835   1791       2
# 7   1835   6435       2
# 8   1835  10037       4
# 9   1835  10697       3

# %% [markdown]
# **1) How many nodes are there?**

# %%
print('Number of nodes:')

actorsdf['id'].nunique()
# Out:
# Number of nodes:
# 17577

# %% [markdown]
# **2) How many edges are there?**

# %%
print('Number of edges:') 

len(edges_actorsdf.index)
# Out:
# Number of edges:
# 287074

# %% [markdown]
# # Degree distribution
#
# Analyse the degree distribution. Compute the total degree distribution.

# %%
df_graph = Graph.DataFrame(edges_actorsdf, directed=False)

actorsdata = df_graph.get_vertex_dataframe()

# %%
actorsdata['amount_of_degrees'] = df_graph.degree(mode='all')

# %% [markdown]
# **3) How does this distributions look like?**

# %%
import plotly.express as px

fig1 = px.histogram(actorsdata, x="amount_of_degrees")
fig1.show()
# Out:
# <div>                            <div id="a17b1fa0-4dbb-42cb-a4f6-1ad1b30afb54" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a17b1fa0-4dbb-42cb-a4f6-1ad1b30afb54")) {                    Plotly.newPlot(                        "a17b1fa0-4dbb-42cb-a4f6-1ad1b30afb54",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"amount_of_degrees=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"type":"histogram","x":[8,40,29,6,42,40,9,7,25,25,42,29,20,9,10,15,15,30,34,16,7,9,27,14,14,34,10,34,42,19,3,22,6,13,20,20,13,2,19,18,25,16,8,12,20,13,30,26,6,6,19,10,23,21,21,2,25,19,39,134,207,60,207,213,216,82,115,55,123,68,190,147,55,88,198,49,65,151,188,56,31,207,160,80,78,81,60,52,150,269,137,183,168,113,66,73,101,110,33,76,229,60,49,172,38,222,402,159,103,93,289,182,160,240,76,20,204,340,53,105,214,112,17,110,109,9,17,490,417,8,262,471,46,121,49,245,48,138,30,54,294,297,24,28,28,209,28,255,225,38,104,231,62,266,28,166,334,320,372,196,493,188,784,463,555,48,319,392,324,180,358,16,105,146,57,500,533,450,106,545,295,365,68,86,92,13,51,41,28,30,43,54,118,96,52,108,18,84,5,121,39,24,177,177,64,96,103,275,3,24,9,13,5,1,25,29,33,11,2,35,8,7,58,12,4,40,2,15,15,34,19,13,37,8,79,29,53,6,22,25,11,35,26,25,13,31,34,1,28,14,6,49,26,29,12,17,4,6,21,71,7,4,23,18,10,35,6,61,4,10,15,12,17,9,20,7,20,30,9,101,19,50,12,20,159,13,28,2,77,23,33,33,21,3,27,16,6,22,107,9,111,11,132,28,35,17,15,8,30,23,10,8,31,2,39,8,11,6,3,33,27,3,5,9,7,9,23,26,5,10,9,15,29,22,28,14,3,11,10,16,10,21,11,13,29,6,21,44,25,29,5,15,7,7,16,28,43,12,11,24,16,62,5,41,50,13,29,25,27,29,20,24,36,24,24,24,38,30,45,35,37,21,21,27,112,149,53,270,25,5,147,46,1,3,4,14,7,3,18,44,187,3,31,121,4,270,561,203,97,22,38,139,5,23,10,22,21,60,25,3,11,6,66,4,34,85,14,3,6,13,11,11,20,75,9,6,2,10,22,12,112,8,40,6,4,22,74,16,1,4,9,104,14,70,50,11,18,43,5,6,9,23,2,4,254,9,50,8,1,4,8,2,1,22,2,79,8,102,5,21,108,18,28,160,24,7,2,13,8,57,46,62,77,2,2,1,11,4,88,16,27,6,361,42,7,26,7,15,14,2,28,9,61,1,5,2,9,4,30,11,16,5,2,2,11,181,120,280,11,74,10,47,4,13,87,145,25,123,105,119,35,13,120,320,34,28,19,99,199,172,103,32,89,111,2,382,74,66,54,71,89,182,278,35,10,37,314,15,48,131,24,280,6,2,19,298,69,11,7,6,1,7,15,8,32,37,33,9,14,2,10,6,39,108,5,2,87,3,106,18,27,60,109,18,40,9,23,81,7,63,187,21,16,40,4,16,77,2,82,97,78,14,119,34,10,15,31,42,83,69,45,8,10,18,75,112,178,31,24,95,127,43,109,22,208,101,93,85,54,98,37,37,32,96,119,196,293,212,64,42,132,79,115,60,63,109,280,74,142,41,121,72,318,31,121,89,120,152,225,161,103,89,11,56,134,333,42,203,144,162,94,202,95,227,40,70,93,457,136,9,103,29,84,197,165,18,84,186,94,111,19,134,324,142,69,25,47,136,133,129,341,207,35,116,141,158,75,111,124,279,162,181,93,86,11,75,149,30,133,106,138,143,16,101,69,168,92,115,15,74,47,76,257,76,30,251,139,40,29,208,20,96,19,30,224,56,24,66,11,8,22,37,34,3,123,62,57,11,45,15,6,38,63,40,17,137,210,40,21,83,75,37,130,105,80,29,107,25,28,194,135,46,40,63,18,50,33,34,12,17,43,53,48,30,9,28,47,27,8,33,40,13,11,186,9,12,6,5,63,5,125,130,36,21,22,14,7,15,97,17,59,55,5,3,16,25,42,24,55,86,12,17,18,8,18,29,37,19,34,81,31,18,46,30,17,14,106,23,105,47,54,39,79,14,14,65,17,13,45,1,57,10,23,9,10,35,55,32,74,2,38,53,136,23,12,14,23,44,40,62,134,45,28,18,35,160,29,7,11,20,68,27,24,50,9,68,22,96,21,64,74,144,53,26,22,66,132,10,56,4,32,36,38,41,10,25,31,19,42,20,30,52,7,14,18,7,24,10,20,26,15,6,6,15,14,23,72,13,18,5,4,10,7,74,21,17,33,12,27,16,41,19,22,16,11,11,22,22,5,22,23,16,109,74,39,38,7,15,20,27,3,10,57,22,11,16,9,31,16,6,15,13,15,28,13,64,33,17,7,3,34,46,6,51,15,29,7,23,58,43,12,48,11,3,8,21,13,12,12,54,18,50,28,31,19,37,16,16,5,50,46,17,99,26,15,55,62,42,33,26,17,54,44,11,15 ...

# %% [markdown]
# **4) What is the maximum degree?**

# %%
max(df_graph.degree())
# Out:
# 784

# %% [markdown]
# **5) What is the minum degree?**

# %%
min(df_graph.degree())
# Out:
# 1

# %% [markdown]
# # Network Diameter and Average Path Length
#
# You have functions in igraph to calculate the diameter and the average path length. Think if you should consider the weights, the directions, etc.
#
# **6) What is the diameter of the graph?**

# %%
df_graph.diameter()
# Out:
# 16

# %% [markdown]
# **7) What is the avg path length of the graph?**

# %%
df_graph.average_path_length()
# Out:
# 4.890545545798965

# %% [markdown]
# # Node importance: Centrality measures
#
# (Optional but recommended): Obtain the distribution of the number of movies made by an actor and the number of genres in which an actor starred in. It may be useful to analyze and discuss the results to be obtained in the following exercises.

# %%
actorsdf['amount_of_genres'] = actorsdf.genres.apply(lambda x: len(x.split(',')) )
actorsdf
# Out:
#           id                 name  movies_95_04 main_genre  \
# 0      15629  Rudder, Michael (I)            12   Thriller
# 1       5026        Morgan, Debbi            16      Drama
# 2      11252         Bellows, Gil            33      Drama
# 3       5150         Dray, Albert            20     Comedy
# 4       4057      Daly, Shane (I)            18      Drama
# ...      ...                  ...           ...        ...
# 17572  16211     Urrutia, Paulina            10    Romance
# 17573   4910        Kay, Lisa (I)            10     Comedy
# 17574   5746   Sutherland, Kiefer            43      Drama
# 17575   1645         Glyde, Billy           182      Adult
# 17576   8474        Scott, Ridley            24     Family
#
#                                                   genres  amount_of_genres
# 0      Action:1,Comedy:1,Drama:1,Fantasy:1,Horror:1,N...                10
# 1      Comedy:2,Documentary:1,Drama:6,Horror:2,NULL:3...                 6
# 2      Comedy:6,Documentary:1,Drama:7,Family:1,Fantas...                11
# 3      Comedy:6,Crime:1,Documentary:1,Drama:4,NULL:5,...                 8
# 4      Comedy:2,Crime:1,Drama:7,Horror:1,Music:1,Musi...                 8
# ...                                                  ...               ...
# 17572          Comedy:1,Drama:2,NULL:4,Romance:2,Short:1                 5
# 17573        Comedy:5,Drama:1,Fantasy:1,NULL:2,Romance:1                 5
# 17574  Action:2,Comedy:3,Documentary:10,Drama:7,Famil...                13
# 17575         Adult:139,Drama:1,NULL:38,Sci-Fi:3,Short:1                 5
# 17576             Documentary:18,Family:2,NULL:2,Short:2                 4
#
# [17577 rows x 6 columns]

# %% [markdown]
# Obtain three vectors with the degree, betweeness and closeness for each vertex of the actors' graph.

# %%
actorsdata['betweeness'] = df_graph.betweenness()
actorsdata['closeness'] = df_graph.closeness()

actorsdata.head(10)
# Out:
#            name  amount_of_degrees     betweeness  closeness
# vertex ID
# 0             0                  8      94.526366   0.168868
# 1             1                 40    9914.327130   0.168930
# 2             2                 29  134403.550820   0.196873
# 3             3                  6     154.697492   0.167262
# 4             4                 42   31566.548050   0.185074
# 5             5                 40   25408.367555   0.181312
# 6             6                  9    1181.540684   0.171957
# 7             7                  7      13.781625   0.157331
# 8             8                 25    1153.017469   0.168902
# 9             9                 25    8810.661314   0.172383

# %% [markdown]
# ---
# Obtain the list of the 20 actors with the largest degree centrality. It can be useful to show a list with the degree, the name of the actor, the number of movies, the main genre, and the number of genres in which the actor has participated.

# %%
centrality_actors = pd.merge(actorsdf,actorsdata, left_on='id', right_on='name')
centrality_actors.sort_values('amount_of_degrees',ascending=False).head(20)
# Out:
#          id               name_x  movies_95_04 main_genre  \
# 12147   162      Davis, Mark (V)           540      Adult
# 1761   1743    Sanders, Alex (I)           467      Adult
# 13442  1754     North, Peter (I)           460      Adult
# 11272  1802          Marcus, Mr.           435      Adult
# 4092    407       Tedeschi, Tony           364      Adult
# 8354    164           Dough, Jon           300      Adult
# 5968    179      Stone, Lee (II)           403      Adult
# 2236    176        Voyeur, Vince           370      Adult
# 5752    175  Lawrence, Joel (II)           315      Adult
# 15511   160    Steele, Lexington           429      Adult
# 16429   127          Ashley, Jay           309      Adult
# 17062  1626            Boy, T.T.           336      Adult
# 10548  2108          Jeremy, Ron           280      Adult
# 8843    131  Cannon, Chris (III)           287      Adult
# 6840    163           Bune, Tyce           267      Adult
# 4524    701           Hanks, Tom            75     Family
# 6587   1778       Michaels, Sean           252      Adult
# 1124    177          Stone, Kyle           278      Adult
# 537    1688        Hardman, Dave           319      Adult
# 11387  1804      Surewood, Brian           244      Adult
#
#                                                   genres  amount_of_genres  \
# 12147  Action:1,Adult:429,Comedy:3,Crime:1,Documentar...                10
# 1761   Action:1,Adult:380,Adventure:1,Comedy:2,Docume...                10
# 13442  Action:1,Adult:389,Documentary:5,Drama:5,NULL:...                 8
# 11272  Adult:343,Crime:1,Documentary:2,NULL:86,Short:...                 6
# 4092   Adult:286,Adventure:1,Comedy:1,Documentary:2,D...                11
# 8354   Adult:248,Adventure:1,Comedy:1,Documentary:1,D...                 8
# 5968   Adult:310,Comedy:1,Documentary:1,Fantasy:2,NUL...                 7
# 2236   Action:1,Adult:303,Comedy:3,Crime:1,Documentar...                10
# 5752   Adult:257,Comedy:1,Documentary:1,Musical:1,NUL...                 7
# 15511  Adult:340,Comedy:1,Documentary:4,Drama:1,Fanta...                 8
# 16429  Adult:247,Adventure:1,Comedy:1,Documentary:2,D...                 8
# 17062  Action:1,Adult:271,Documentary:5,Drama:4,NULL:...                 8
# 10548  Adult:149,Adventure:1,Animation:1,Comedy:15,Do...                14
# 8843   Action:1,Adult:226,Comedy:2,Documentary:4,Dram...                 9
# 6840        Adult:213,Comedy:3,Fantasy:2,NULL:48,Short:1                 5
# 4524   Animation:3,Comedy:5,Documentary:32,Drama:6,Fa...                13
# 6587   Adult:203,Documentary:4,Drama:1,Fantasy:1,NULL...                 6
# 1124   Adult:212,Comedy:3,Documentary:2,Fantasy:4,NUL...                 8
# 537    Adult:240,Adventure:1,Comedy:2,Drama:3,NULL:67...                 7
# 11387  Adult:190,Comedy:2,Fantasy:1,Horror:1,NULL:49,...                 6
#
#        name_y  amount_of_degrees    betweeness  closeness
# 12147     162                784  9.318531e+05   0.249300
# 1761     1743                610  5.572365e+05   0.245821
# 13442    1754                599  4.173385e+05   0.241765
# 11272    1802                584  1.463808e+06   0.249964
# 4092      407                561  6.721635e+05   0.245693
# 8354      164                555  8.636479e+05   0.248562
# 5968      179                545  3.393109e+05   0.238488
# 2236      176                533  3.810606e+05   0.245783
# 5752      175                500  2.851236e+05   0.241337
# 15511     160                493  2.971735e+05   0.240841
# 16429     127                490  1.794342e+05   0.238661
# 17062    1626                475  2.177450e+05   0.240556
# 10548    2108                471  9.748544e+06   0.282720
# 8843      131                471  5.315881e+05   0.247557
# 6840      163                463  3.241937e+05   0.236232
# 4524      701                457  1.977252e+06   0.305231
# 6587     1778                451  3.383991e+05   0.243856
# 1124      177                450  1.032512e+05   0.235648
# 537      1688                438  2.977737e+05   0.240841
# 11387    1804                428  1.729722e+05   0.237955

# %% [markdown]
# **8) Who is the actor with highest degree centrality?**
#
# The actor with highest degree centrality: **Mark Davis**

# %% [markdown]
# **9) How do you explain the high degree of the top-20 list??**

# %% [markdown]
# The degree centrality has a clear increase since a lot of actors participate in several moviees.  We can find an outliar with Tom Hanks who has a high amount of degrees due to his high level of popularity and is not from the adult movie industry.
# Adult movies actors are able to act in more movies than hollywood actors since they are shorter and cheaper.

# %% [markdown]
# Obtain the list of the 20 actors with the largest betweenness centrality. Show a list with the betweenness, the name of the actor, the number of movies, the main genre, and the number of genres in which the actor has participated.

# %%
centrality_actors.sort_values('betweeness',ascending=False).head(20)
# Out:
#           id                name_x  movies_95_04 main_genre  \
# 10548   2108           Jeremy, Ron           280      Adult
# 4693    3284      Chan, Jackie (I)            59     Comedy
# 2563     564        Cruz, Penélope            46      Drama
# 14433  14458      Shahlavi, Darren            16     Action
# 15720  17308  Del Rosario, Monsour            20     Action
# 17458    285     Depardieu, Gérard            56     Comedy
# 8799   13723     Bachchan, Amitabh            35    Romance
# 10412   1529    Jackson, Samuel L.            97      Drama
# 5517    5083     Soualem, Zinedine            65     Comedy
# 15894   1923       Del Rio, Olivia            84      Adult
# 559     2549      Jaenicke, Hannes            66   Thriller
# 15834   2623          Hayek, Salma            44      Drama
# 568    13698                  Pelé            10    Romance
# 4157    4628        Knaup, Herbert            50      Drama
# 9655    3213      Goldberg, Whoopi           109     Comedy
# 13349   4550         Roth, Cecilia            23      Drama
# 246     3075      Bellucci, Monica            43      Drama
# 4524     701            Hanks, Tom            75     Family
# 5906    1057      August, Pernilla            31      Drama
# 1531    5295             Kier, Udo            69      Drama
#
#                                                   genres  amount_of_genres  \
# 10548  Adult:149,Adventure:1,Animation:1,Comedy:15,Do...                14
# 4693   Action:2,Comedy:13,Crime:4,Documentary:18,Fami...                12
# 2563   Adventure:1,Comedy:2,Documentary:5,Drama:6,Fam...                13
# 14433  Action:4,Comedy:3,Documentary:1,Drama:1,Fantas...                 9
# 15720  Action:8,Drama:3,Fantasy:1,Horror:2,NULL:1,Rom...                 9
# 17458  Adventure:1,Comedy:15,Crime:2,Documentary:11,D...                11
# 8799   Action:1,Comedy:1,Crime:1,Documentary:1,Drama:...                13
# 10412  Action:3,Adventure:1,Comedy:3,Crime:3,Document...                14
# 5517   Animation:1,Comedy:17,Crime:3,Documentary:1,Dr...                12
# 15894  Adult:64,Drama:1,Fantasy:2,NULL:14,Sci-Fi:1,Sh...                 6
# 559    Action:2,Adventure:2,Comedy:3,Crime:10,Drama:1...                12
# 15834  Adventure:1,Animation:1,Comedy:3,Crime:2,Docum...                14
# 568              Comedy:1,Documentary:5,NULL:3,Romance:1                 4
# 4157   Action:1,Adult:1,Comedy:4,Crime:5,Drama:14,NUL...                11
# 9655   Adventure:3,Animation:1,Comedy:16,Documentary:...                14
# 13349  Comedy:1,Documentary:2,Drama:11,Family:3,Horro...                 8
# 246    Adventure:1,Comedy:4,Documentary:7,Drama:8,Fam...                12
# 4524   Animation:3,Comedy:5,Documentary:32,Drama:6,Fa...                13
# 5906   Action:2,Documentary:4,Drama:14,Family:1,Music...                10
# 1531   Action:2,Animation:2,Comedy:10,Crime:2,Documen...                15
#
#        name_y  amount_of_degrees    betweeness  closeness
# 10548    2108                471  9.748544e+06   0.282720
# 4693     3284                135  4.716909e+06   0.287238
# 2563      564                182  4.330663e+06   0.295555
# 14433   14458                  8  4.295503e+06   0.193886
# 15720   17308                  6  4.267099e+06   0.163154
# 17458     285                159  4.037356e+06   0.278351
# 8799    13723                 66  2.570247e+06   0.226349
# 10412    1529                427  2.539614e+06   0.309265
# 5517     5083                121  2.368164e+06   0.249825
# 15894    1923                168  2.316388e+06   0.240033
# 559      2549                 73  2.136980e+06   0.250736
# 15834    2623                185  2.117390e+06   0.288701
# 568     13698                  7  2.098485e+06   0.192619
# 4157     4628                 63  2.062585e+06   0.231765
# 9655     3213                398  2.051621e+06   0.307760
# 13349    4550                 62  2.019247e+06   0.244677
# 246      3075                 81  2.006221e+06   0.273986
# 4524      701                457  1.977252e+06   0.305231
# 5906     1057                 44  1.937362e+06   0.256443
# 1531     5295                 64  1.919261e+06   0.281793

# %% [markdown]
# **10) Who is the actor with highest betweenes?**
#
# The actor with the highest betweenes: **Ron Jeremy**

# %% [markdown]
# **11) How do you explain the high betweenness of the top-20 list?**
#
# We can see a correlation betweeen famous actors such as Samuel L. Jackson and Salma Hayek who have high levels of betweeness due to their celebrity profiles and hollywood stars.

# %% [markdown]
# Obtain the list of the 20 actors with the largest closeness centrality. Show a list with the closeness the name of the actor, the number of movies, the main genre, and the number of genres in which the actor has participated.

# %%
centrality_actors[centrality_actors['closeness'] < 1].sort_values('closeness',ascending=False).head(20)
# Out:
#           id                   name_x  movies_95_04 main_genre  \
# 2109   16747          Armanis, Julian            12      Adult
# 14828  13582             Fazira, Erra            13    Romance
# 13001  16913            Lim, Kay Tong            11      Drama
# 6367   17822            Lee, Mark (X)            10     Comedy
# 17467  13581       Hassan, Jalaluddin            14    Romance
# 2567   17804              Kovac, Erik            11      Adult
# 9514   17803              Sulik, Dano            21      Adult
# 7288   16740           Novotny, Pavel            15      Adult
# 6659   16745        Bonnet, Sebastian            17      Adult
# 5377   16748             Davidov, Ion            10      Adult
# 12756  13064         Ridgeston, Lukas            10      Adult
# 11593  13289            Ahn, Sung-kee            22    Romance
# 2320   16746            Paulik, Johan            14      Adult
# 17543  13293             Lee, Beom-su            19    Romance
# 85     17022            Klauzner, Uri            15      Drama
# 2632   17671  Pyrpassopoulos, Giorgos            11     Comedy
# 17103  16741          Hanak, Ales (I)            15      Adult
# 13875  16742          Korsakov, Pavel            10      Adult
# 16262  16744               Kajc, Cage            11      Adult
# 12734  17846   Kafetzopoulos, Antonis            13     Comedy
#
#                                                   genres  amount_of_genres  \
# 2109                              Adult:11,Documentary:1                 2
# 14828               Animation:1,Crime:1,NULL:2,Romance:9                 4
# 13001  Comedy:3,Drama:3,Romance:2,Short:1,Thriller:1,...                 6
# 6367   Comedy:4,Crime:2,Drama:1,Family:1,NULL:1,Roman...                 6
# 17467         Comedy:1,Drama:5,NULL:1,Romance:6,Sci-Fi:1                 5
# 2567                        Adult:8,Documentary:1,NULL:2                 3
# 9514             Adult:17,Documentary:1,NULL:2,Romance:1                 4
# 7288                                            Adult:15                 1
# 6659             Adult:14,Documentary:1,NULL:1,Romance:1                 4
# 5377                        Adult:7,Documentary:1,NULL:2                 3
# 12756                       Adult:6,Documentary:2,NULL:2                 3
# 11593  Action:2,Comedy:3,Drama:3,Fantasy:1,Mystery:1,...                 9
# 2320              Adult:5,Documentary:2,NULL:6,Romance:1                 4
# 17543  Action:1,Comedy:4,Drama:4,Family:1,Horror:1,NU...                 8
# 85                Action:1,Crime:1,Drama:9,Short:1,War:3                 5
# 2632           Comedy:4,Drama:2,NULL:2,Romance:2,Short:1                 5
# 17103                                           Adult:15                 1
# 13875                                           Adult:10                 1
# 16262                                    Adult:10,NULL:1                 2
# 12734                  Comedy:6,Drama:2,NULL:1,Romance:4                 4
#
#        name_y  amount_of_degrees  betweeness  closeness
# 2109    16747                  6   24.000000   0.714286
# 14828   13582                  1    0.000000   0.666667
# 13001   16913                  1    0.000000   0.666667
# 6367    17822                  1    0.000000   0.666667
# 17467   13581                  1    0.000000   0.666667
# 2567    17804                  6    1.000000   0.588235
# 9514    17803                  6    1.000000   0.588235
# 7288    16740                  4   21.000000   0.588235
# 6659    16745                  6    1.000000   0.588235
# 5377    16748                  6    1.000000   0.588235
# 12756   13064                  6    1.000000   0.588235
# 11593   13289                  4  108.166667   0.458333
# 2320    16746                  5    0.000000   0.454545
# 17543   13293                  7  115.666667   0.448980
# 85      17022                  8  109.700000   0.428571
# 2632    17671                  7   96.183333   0.421053
# 17103   16741                  3    0.000000   0.416667
# 13875   16742                  3    0.000000   0.416667
# 16262   16744                  3    0.000000   0.416667
# 12734   17846                  6  145.450000   0.405063

# %% [markdown]
# **12) Who is the actor with highest closeness centrality?**
#
# The actor with the highest closeness centrality is **Julian Armanis** with 0.714286

# %% [markdown]
# **13) How do you explain the high closeness of the top-20 list?**
#
# We can appreciate how the top 20 actors have strong interactions due to their short average distance to others.  Technically, it's shorter for nodes to reach these top 20 actors.
